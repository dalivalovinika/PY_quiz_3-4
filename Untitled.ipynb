# %%
#L6 - გამოიყენეთ მონაცემთა წმედის რომელიმე ფუნქციონალი (მაგ. რომელიმე სვეტის მონაცემები
# გადაანაწილეთ რამდენიმე ახალ სვეტად, წაშალეთ რომელიმე სვეტი, ცარიელი მნიშვნელობებისთვის
# გამოიყენეთ სასურველი ფორმატი, ა.შ.)

# %%
import pandas as pd
import warnings

# %%
df = pd.read_csv("Earthquakes_database.csv")
df.head()
# Out:
#        Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  1/2/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  1/4/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  1/5/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  1/8/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  1/9/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic
#
# [5 rows x 21 columns]

# %%
df.pop('Status')
df.head()
# Out:
#        Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  1/2/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  1/4/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  1/5/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  1/8/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  1/9/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  Magnitude Error  \
# 0                     NaN        6.0             MW              NaN
# 1                     NaN        5.8             MW              NaN
# 2                     NaN        6.2             MW              NaN
# 3                     NaN        5.8             MW              NaN
# 4                     NaN        5.8             MW              NaN
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source
# 0           ISCGEM
# 1           ISCGEM
# 2           ISCGEM
# 3           ISCGEM
# 4           ISCGEM

# %%
# (L7 – 3 ქულა) რიცხვითი ტიპის ველის მონაცემები დაყავით კატეგორიებად cut() ფუნქციის გამოყენებით (მაგ.
# ასაკის ველი 3 კატეგორიად „Children”, “Adolescent”, “Old”). შესაბამისად დაამატეთ კატეგორიის სვეტი.

# %%
bins = [0, 5.4, 5.9, float('inf')]

labels = ['Normal', 'Hard', 'Very Hard']

df['Magnitude_Category'] = pd.cut(df['Magnitude'], bins=bins, labels=labels)
df.head()
# Out:
#        Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  1/2/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  1/4/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  1/5/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  1/8/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  1/9/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source Magnitude_Category
# 0           ISCGEM          Very Hard
# 1           ISCGEM               Hard
# 2           ISCGEM          Very Hard
# 3           ISCGEM               Hard
# 4           ISCGEM               Hard
#
# [5 rows x 21 columns]

# %%
# (L9 – 3 ქულა) გამოიყენეთ მონაცემთა “Reshaping”-ის ჩამოთვლილი ფუნქციებიდან რომელიმე 2 მათგანი
# (stack(), unstack(), melt(), pivot(), explode(), pivot_table(), Crosstab())

# %%
stacked_df = df.stack()
unstacked_df = stacked_df.unstack()

# %%
# (L10 - 3 ქულა) ააგეთ თქვენთვის სასურველი 4 განსხვავებული დიაგრამა შემდეგი ტიპებიდან (ხაზოვანი
# დიაგრამა, სვეტოვანი დიაგრამა, გაფანტულობის დიაგრამა, წრიული დიაგრამა, ჰისტოგრამა).

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.index, df['Magnitude'])

plt.title('Magnitude')
plt.xlabel('Index')
plt.ylabel('Magnitude')


plt.show()

# %%
plt.hist(df['Magnitude'], bins=10, color='blue', edgecolor='black')

plt.title('Magnitude')
plt.xlabel('Magnitude')
plt.ylabel('Frequence')

plt.show()

# %%
plt.pie(df['Magnitude'], labels=df['Magnitude_Category'], autopct='%1.1f%%', startangle=90)


plt.title('Magnitude')

plt.show()

# %%
plt.bar(df.index, df['Magnitude']) 

plt.title('Magnitude')
plt.xlabel('Index')
plt.ylabel('Magnitude')

plt.show()

# %%
# (L11 – 2 ქულა) გამოიყენეთ თარიღებთან სამუშაო მინიმუმ 2 განსხვავებული ფუნქცია/ტრანსფორმაცია
# სურვილისამებრ (მაგ. resample ფუნქცია).

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df['weekday'] = df['Date'].dt.day_name()
df.head()
# Out:
#         Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0 1965-01-02  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1 1965-01-04  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2 1965-01-05  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3 1965-01-08  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4 1965-01-09  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Azimuthal Gap  \
# 0                     NaN        6.0             MW  ...            NaN
# 1                     NaN        5.8             MW  ...            NaN
# 2                     NaN        6.2             MW  ...            NaN
# 3                     NaN        5.8             MW  ...            NaN
# 4                     NaN        5.8             MW  ...            NaN
#
#    Horizontal Distance  Horizontal Error  Root Mean Square            ID  \
# 0                  NaN               NaN               NaN  ISCGEM860706
# 1                  NaN               NaN               NaN  ISCGEM860737
# 2                  NaN               NaN               NaN  ISCGEM860762
# 3                  NaN               NaN               NaN  ISCGEM860856
# 4                  NaN               NaN               NaN  ISCGEM860890
#
#    Source Location Source Magnitude Source Magnitude_Category   weekday
# 0  ISCGEM          ISCGEM           ISCGEM          Very Hard  Saturday
# 1  ISCGEM          ISCGEM           ISCGEM               Hard    Monday
# 2  ISCGEM          ISCGEM           ISCGEM          Very Hard   Tuesday
# 3  ISCGEM          ISCGEM           ISCGEM               Hard    Friday
# 4  ISCGEM          ISCGEM           ISCGEM               Hard  Saturday
#
# [5 rows x 22 columns]

# %%
df_2016 = df[df['Date'].dt.year == 2016]

# %%
df_2016
# Out:
#             Date      Time  Latitude  Longitude        Type   Depth  \
# 22943 2016-01-01   2:00:40  -50.5575   139.4489  Earthquake   10.00
# 22944 2016-01-01  15:02:17  -28.6278  -177.2810  Earthquake   34.00
# 22945 2016-01-02   4:22:20   44.8069   129.9406  Earthquake  585.47
# 22946 2016-01-03  23:05:22   24.8036    93.6505  Earthquake   55.00
# 22947 2016-01-05   2:21:11   30.6132   132.7337  Earthquake    4.71
# ...          ...       ...       ...        ...         ...     ...
# 23407 2016-12-28   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408 2016-12-28   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409 2016-12-28  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410 2016-12-29  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411 2016-12-30  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 22943          1.6                     NaN        6.3            MWW  ...
# 22944          1.2                     NaN        5.8            MWW  ...
# 22945          3.6                     NaN        5.8            MWW  ...
# 22946          1.8                     NaN        6.7            MWW  ...
# 22947          3.2                     NaN        5.8            MWW  ...
# ...            ...                     ...        ...            ...  ...
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Azimuthal Gap  Horizontal Distance  Horizontal Error  Root Mean Square  \
# 22943          19.00                9.361               6.9            0.8800
# 22944          62.00                0.837               7.8            1.2800
# 22945          12.00                0.311               8.1            0.8900
# 22946          16.00                1.794               4.5            1.0100
# 22947          29.00                2.151               2.0            0.4800
# ...              ...                  ...               ...               ...
# 23407          42.47                0.120               NaN            0.1898
# 23408          48.58                0.129               NaN            0.2187
# 23409          91.00                0.992               4.8            1.5200
# 23410          26.00                3.553               6.0            1.4300
# 23411          97.00                0.681               4.5            0.9100
#
#                ID  Source Location Source Magnitude Source Magnitude_Category  \
# 22943  US10004ANT      US              US               US          Very Hard
# 22944  US10004AQY      US              US               US               Hard
# 22945  US10004ATB      US              US               US               Hard
# 22946  US10004B2N      US              US               US          Very Hard
# 22947  US10004BEN      US              US               US               Hard
# ...           ...     ...             ...              ...                ...
# 23407  NN00570710      NN              NN               NN               Hard
# 23408  NN00570744      NN              NN               NN               Hard
# 23409  US10007NAF      US              US               US               Hard
# 23410  US10007NL0      US              US               US          Very Hard
# 23411  US10007NTD      US              US               US               Hard
#
#          weekday
# 22943     Friday
# 22944     Friday
# 22945   Saturday
# 22946     Sunday
# 22947    Tuesday
# ...          ...
# 23407  Wednesday
# 23408  Wednesday
# 23409  Wednesday
# 23410   Thursday
# 23411     Friday
#
# [469 rows x 22 columns]
